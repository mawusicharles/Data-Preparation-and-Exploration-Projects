# %% [markdown]
# ### Collecting Ecological Footprint Data
#
# #### By Charles MAWUSI

# %%
# Import the requests package 
import requests

# %%
results =requests.get("https://api.footprintnetwork.org/v1/data/3/all/")
results.status_code
# Out:
# 200

# %%
results.text
# Out:
# '[{"year":1961,"shortName":"Albania","countryCode":3,"countryName":"Albania","isoa2":"AL","score":"3A","record":"AreaPerCap","cropLand":0.293318857122794,"grazingLand":0.577293466492859,"forestLand":0.835937686216223,"fishingGround":0.382338649301076,"builtupLand":0.0171926171040335,"carbon":0.0,"value":2.10608127623698},{"year":1962,"shortName":"Albania","countryCode":3,"countryName":"Albania","isoa2":"AL","score":"3A","record":"AreaPerCap","cropLand":0.290245649171565,"grazingLand":0.555936913559328,"forestLand":0.80661422507051,"fishingGround":0.370952253702032,"builtupLand":0.0171926182903457,"carbon":0.0,"value":2.04094165979378},{"year":1963,"shortName":"Albania","countryCode":3,"countryName":"Albania","isoa2":"AL","score":"3A","record":"AreaPerCap","cropLand":0.287168850610627,"grazingLand":0.536083532607591,"forestLand":0.776653339305415,"fishingGround":0.359997106695512,"builtupLand":0.0171926862409809,"carbon":0.0,"value":1.97709551546013},{"year":1964,"shortName":"Albania"
# ...

# %%
results.json()
# Out:
# [{'year': 1961,
#   'shortName': 'Albania',
#   'countryCode': 3,
#   'countryName': 'Albania',
#   'isoa2': 'AL',
#   'score': '3A',
#   'record': 'AreaPerCap',
#   'cropLand': 0.293318857122794,
#   'grazingLand': 0.577293466492859,
#   'forestLand': 0.835937686216223,
#   'fishingGround': 0.382338649301076,
#   'builtupLand': 0.0171926171040335,
#   'carbon': 0.0,
#   'value': 2.10608127623698},
#  {'year': 1962,
#   'shortName': 'Albania',
#   'countryCode': 3,
#   'countryName': 'Albania',
#   'isoa2': 'AL',
#   'score': '3A',
#   'record': 'AreaPerCap',
#   'cropLand': 0.290245649171565,
#   'grazingLand': 0.555936913559328,
#   'forestLand': 0.80661422507051,
#   'fishingGround': 0.370952253702032,
#   'builtupLand': 0.0171926182903457,
#   'carbon': 0.0,
#   'value': 2.04094165979378},
#  {'year': 1963,
#   'shortName': 'Albania',
#   'countryCode': 3,
#   'countryName': 'Albania',
#   'isoa2': 'AL',
#   'score': '3A',
#   'record': 'AreaPerCap',
# ...
